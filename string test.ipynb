# %% [markdown]
# # 1.

# %% [markdown]
# # Q2

# %%
# we are using + opreator when we use Arthmathical Opreator for adding ,and stick a few word together 
#join method to join 2 words or more word from a list sentence in 1 line

string = "hello"
string_2 = "sakshi"
print(string+" "+string_2)
# Out:
#   Cell In[37], line 2
#     join method to join 2 words or more word from a list sentence in 1 line
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Q3

# %%
string = "sakshi"
print(string.find(" "))
# Out:
# -1

# %% [markdown]
# # Q4

# %%
string = "sakshi"
print(len(string))
# Out:
# 6

# %% [markdown]
# # Q5

# %%
string = "hello sakshi"
string.upper()
# Out:
# 'HELLO SAKSHI'

# %% [markdown]
# # Q6

# %%
string = "HELLO SAKSHI"
string.lower()
# Out:
# 'hello sakshi'

# %% [markdown]
# # Q7

# %%
string = "Are you ready"
string.replace("ready","crying",1)
# Out:
# 'Are you crying'

# %% [markdown]
# # Q8

# %%
string ="I am new in this class"
string.split("in")
# Out:
# ['I am new ', ' this class']

# %% [markdown]
# # Q9

# %%
string = "This is a python class"
string.startswith("This")
# Out:
# True

# %% [markdown]
# # Q 10

# %%
string = "This is a python class"
string.endswith("class")
# Out:
# True

# %% [markdown]
# # Q11

# %%
string = "   python  "
string.strip()
# Out:
# 'python'

# %% [markdown]
# # Q12

# %%
string =  "sakshi sinha"
string.index("a")
# Out:
# 1

# %% [markdown]
# # Q13

# %%
string = "I am new in this class"
string.count("i")
# Out:
# 2

# %% [markdown]
# # Q14

# %%
string = "Sakshi272387"
string.isalpha()
# Out:
# False

# %%
string = "Sakshi"
string.isalpha()
# Out:
# True

# %% [markdown]
# # Q15

# %%
string = "sakshi234"
string.isnumeric()
# Out:
# False

# %%
string = "234"
string.isnumeric()
# Out:
# True

# %% [markdown]
# # Q16

# %% [markdown]
# # Q17

# %%
string = "Sakshi"
print(string[-1])
print(string[-2])
print(string[-3])
print(string[-4])
print(string[-5])
print(string[-6])
# Out:
# i
# h
# s
# k
# a
# S

# %% [markdown]
# # Q18

# %%
n

# %% [markdown]
# # Q19

# %% [markdown]
# # Q20

# %%
string = "This is a Laptop"
string.replace("a"," " ,1)
# Out:
# 'This is   Laptop'
